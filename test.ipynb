# %%
my_dict = {"a" : "u" , "b" : "momma"}

test = "cheers"

test.upper()

for i in test:
    print(i)

print(test)
print(type(test))
print(type(type(test)))

print("END")
# Out:
# c
# h
# e
# e
# r
# s
# cheers
# <class 'str'>
# <class 'type'>
# END

# %%
with open("test.txt", "w") as file:
    file.write("A")

# %%
	
my_dict = ('pen':2.1, 'eraser':0.5)
# Out:
#   Cell In[6], line 1
#     my_dict = ('pen':2.1, 'eraser':0.5)
#                     ^
# SyntaxError: invalid syntax

# %%
d = [ (1,"x") , (2,"y"), (3,"z") ]

print(dict(d))
# Out:
# {1: 'x', 2: 'y', 3: 'z'}

# %%
def words(word):
    one = [1,2]
    two = 3
    return one, two

print(words(words(1)))
# Out:
# ([1, 2], 3)
